# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **1.Find out how many countries are there in the dataset**

# %%
Data['country'].count()
# Out:
# 196

# %% [markdown]
# There are 196 countries in the given dataset

# %% [markdown]
# **2. Examine the data by using visualizations**

# %%
Data.head()
# Out:
#                country  ... International trade: Imports (million US$)
# 0          Afghanistan  ...                                       3568
# 1              Albania  ...                                       4669
# 2              Algeria  ...                                      47091
# 3               Angola  ...                                       8790
# 4  Antigua and Barbuda  ...                                        491
#
# [5 rows x 7 columns]

# %% [markdown]
# **Pie Chart displaying Regionwise percentage distribution of the given dataset**

# %%
Region=Data['Region'].value_counts()   
plot = Region.plot.pie(y='Region', figsize=(12, 12),autopct='%1.2f%%',title='Region',ylabel='',shadow=True, startangle=45)

# %% [markdown]
# **Bar diagram showing popuation in different regions**

# %%
plt.figure(figsize=(10,5))
Region=Data['Region']
Population=Data['Population in thousands (2017)']
plot=plt.bar(Region,Population)
plt.title('Population v/s Region',fontsize=20)
plt.xticks(rotation='90')
plt.xlabel('Region')
plt.ylabel('Population in thousands (2017)')
#plt.grid()
# Out:
# Text(0, 0.5, 'Population in thousands (2017)')

# %% [markdown]
# **Barplot displaying GDP per capita in different regions**

# %%
DataNew=Data.sort_values(by=["GDP per capita (current US$)","country"],ascending=False).head(196)
plt.figure(figsize = (15,8))
plt.title('GDP per capita in Regions',fontsize=15)
plt.xticks(rotation=90)
graph_whole1=sns.barplot(DataNew['Region'],data_whole1['GDP per capita (current US$)']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Bar plot of countries with top five GDP per capita**

# %%
datanew=Data.sort_values(by=['GDP per capita (current US$)','country'],ascending=False).head()
g1=sns.barplot(datanew['country'],datanew['GDP per capita (current US$)'])
plt.title('GDP per capita (current US$)',fontsize=15)
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **3. Find out how many countries with respect to the region are available in the dataset**

# %%
NewData1=Data[["Region", "country"]].groupby("Region").count()
NewData1.sort_values('country', ascending=False)
# Out:
#                    country
# Region
# WesternAsia             18
# EasternAfrica           17
# Caribbean               16
# WesternAfrica           15
# SouthernEurope          12
# SouthAmerica            12
# South-easternAsia       11
# NorthernEurope          10
# EasternEurope           10
# MiddleAfrica             9
# SouthernAsia             9
# CentralAmerica           8
# EasternAsia              7
# WesternEurope            7
# NorthernAfrica           5
# Polynesia                5
# Melanesia                5
# SouthernAfrica           5
# CentralAsia              5
# NorthernAmerica          4
# Micronesia               4
# Oceania                  2

# %% [markdown]
# **4.On average which region has the highest  a)GDP per capita (current US$) b) International trade:Imports (million US$)**

# %% [markdown]
# a) Highest GDP per capita

# %%
NewData2=Data.groupby('Region')['GDP per capita (current US$)'].mean().round(2).sort_values()
NewData2
# Out:
# Region
# WesternAfrica         1013.14
# EasternAfrica         2088.85
# SouthernAsia          2968.40
# MiddleAfrica          3928.83
# NorthernAfrica        3934.96
# SouthernAfrica        4191.90
# CentralAsia           4329.88
# Micronesia            5008.30
# CentralAmerica        6348.14
# SouthAmerica          8499.78
# Polynesia             8686.52
# Melanesia             9261.96
# EasternEurope         9292.49
# South-easternAsia    10299.03
# SouthernEurope       14462.74
# Caribbean            15135.56
# WesternAsia          17013.94
# EasternAsia          27967.61
# NorthernEurope       42098.22
# Oceania              44823.25
# WesternEurope        55387.13
# NorthernAmerica      57659.00
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# NorthernAmerica has the highest GDP per capita (57659.00)

# %% [markdown]
# b)Internationaltrade:Imports(millionUS)

# %%
NewData3=Data.groupby('Region')['International trade: Imports (million US$)'].mean().round(2).sort_values()
NewData3
# Out:
# Region
# Micronesia               99.00
# Polynesia               432.00
# Melanesia              2896.40
# Caribbean              3057.31
# MiddleAfrica           4381.22
# EasternAfrica          4726.18
# WesternAfrica          4898.33
# CentralAsia           12063.40
# SouthernAfrica        18005.60
# SouthAmerica          32885.67
# NorthernAfrica        35034.40
# WesternAsia           46025.56
# CentralAmerica        57031.50
# SouthernAsia          58199.33
# SouthernEurope        76666.67
# EasternEurope         85243.90
# South-easternAsia     98324.64
# Oceania              112914.50
# NorthernEurope       113407.20
# WesternEurope        407498.43
# EasternAsia          451995.00
# NorthernAmerica      663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# Again NorthernAmerica has got highestinternational trade:imports(663552.25)

# %% [markdown]
# **5.Find out which region has more consistent with respect to GDP per capita (current US$)**

# %%
NewData4=Data.groupby('Region')['GDP per capita (current US$)'].std().round(2).sort_values()
NewData4
# Out:
# Region
# WesternAfrica          815.10
# NorthernAfrica         974.71
# SouthernAfrica        2177.55
# SouthernAsia          2855.71
# EasternAfrica         3716.13
# CentralAsia           4152.22
# CentralAmerica        4180.44
# SouthAmerica          4273.71
# Micronesia            4820.67
# MiddleAfrica          5274.85
# EasternEurope         5415.49
# Polynesia             6956.25
# Oceania               9233.33
# SouthernEurope        9541.70
# Melanesia            13855.84
# Caribbean            14579.37
# South-easternAsia    16311.81
# WesternAsia          18812.15
# NorthernEurope       20671.03
# WesternEurope        24770.47
# NorthernAmerica      25749.62
# EasternAsia          27485.12
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# From the standard deviation analysis it is clear that WesternAfrica has got the least value (815.10) and hence this region is more consistent with respect to GDP per capita
